# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.dates as mdates
import numpy as np
import seaborn as sns
import shutil

pd.set_option('display.max_columns', None) # Display all the columns

sns.set()
sns.set_style("whitegrid") # Seaborn style

# %%
# Generate it with git-quick-stats -d in each folder, then copy and paste them in the same .csv file
# https://github.com/arzzen/git-quick-stats
data = pd.read_csv("csv/outcomes02.csv")

# %%
# Set index by repository
data1 = data.set_index("Repository")

# %%
# Transform the date from string to datetime
data1["Date"] = pd.to_datetime(data1["Date"])

# %%
# Create a time series dataframe
profile = data1.pivot_table(index='Date',columns='Repository',values='Commits')

# %%
# Configure font
matplotlib.rcParams['font.sans-serif'] = "Hack"
matplotlib.rcParams['font.family'] = "sans-serif"
sns.set_context("paper")

# Plot the data
my_colors = sns.color_palette("Paired", len(profile.columns)) # Set color palette
ax = profile.plot(color=my_colors, alpha=0.75, rot=0, figsize=(30,10), linewidth=2)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Commits', fontsize=16)
#plt.title("Activity in GitHub research repositories", fontsize=22, y=1.02, fontweight="500")

# Time ticks
# 4 Months ticks
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.gcf().autofmt_xdate()
plt.legend(prop={'size': 12})

# Fix y axis limits
plt.ylim(0, 40)

plt.savefig("svg/outcomes02.svg", bbox_inches="tight")
plt.savefig("png/outcomes02.png", dpi=300, bbox_inches="tight")
