# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
import shutil

from textwrap import wrap

pd.set_option('display.max_columns', None) # Display all the columns

sns.set()
#sns.set_style("whitegrid") # Seaborn style

# %%
data = pd.read_csv("csv/results.csv")

# %%
profile = data["Q21"].str.strip().fillna(value="No answer").value_counts(dropna=False)
profile_percentage = data["Q21"].str.strip().fillna(value="No answer").value_counts(normalize=True, dropna=False) * 100

order = [
    "I did not notice any organized systems, the differences between these entities were not clear",
    "There was at least sometimes a system with a certain structure, and I understood it",
    "There was at least sometimes a system with a certain structure, and I understood it and designed it with the others",
    "No answer"
]
profile = profile.reindex(order).fillna(value=0)
profile_percentage = profile_percentage.reindex(order).fillna(value=0)

print "Data:"
print profile
print ""
print "Data %:"
print profile_percentage
# Out:
# Data:
# I did not notice any organized systems, the differences between these entities were not clear                          1
# There was at least sometimes a system with a certain structure, and I understood it                                    3
# There was at least sometimes a system with a certain structure, and I understood it and designed it with the others    2
# No answer                                                                                                              2
# Name: Q21, dtype: int64
#
# Data %:
# I did not notice any organized systems, the differences between these entities were not clear                          12.5
# There was at least sometimes a system with a certain structure, and I understood it                                    37.5
# There was at least sometimes a system with a certain structure, and I understood it and designed it with the others    25.0
# ...

# %%
# Configure font
matplotlib.rcParams['font.sans-serif'] = "Fira Sans"
matplotlib.rcParams['font.family'] = "sans-serif"
sns.set_context("paper")
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel('Count', fontsize=16)
plt.ylabel('Participants', fontsize=16)
title = "Q21. How did you experience the whole systems (actors, roles, interactions, organizations, places) in your open and making practice so far?"
plt.title("\n".join(wrap(title, 70)), fontsize=22, y=1.02, fontname='Fira Sans', fontweight="500")
my_colors = sns.color_palette("husl", len(profile)) # Set color palette
profile.plot(kind='barh', color=my_colors, alpha=0.75, rot=0, figsize=(15,10))
labels = ['\n'.join(wrap(l, 30)) for l in profile.index]
plt.yticks(range(len(labels)), labels, fontsize=14)
plt.xticks(fontsize=14)
for i, v in enumerate(profile):
    plt.text(v + .1, i, str(v)+" ("+str(profile_percentage[i])+"%)", fontweight='500', fontsize=14)
plt.savefig("svg/Q21.svg", bbox_inches="tight")
plt.savefig("png/Q21.png", dpi=300, bbox_inches="tight")
