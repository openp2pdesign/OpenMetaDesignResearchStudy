# %%
# -*- coding: UTF-8 -*-

# Render our plots inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
import shutil

from textwrap import wrap

pd.set_option('display.max_columns', None) # Display all the columns

sns.set()
#sns.set_style("whitegrid") # Seaborn style

# %%
data = pd.read_csv("csv/results.csv")

# %%
profile = data["Q29"].str.strip().fillna(value="No answer").value_counts(dropna=False)
profile_percentage = data["Q29"].str.strip().fillna(value="No answer").value_counts(normalize=True, dropna=False) * 100

order = [
    "I did not notice an organized system, the differences between these entities were not clear",
    "There was a system with a certain structure, and I understood it",
    "There was a system with a certain structure, and I understood it and designed it with the others",
    "No answer"
]
profile = profile.reindex(order).fillna(value=0)
profile_percentage = profile_percentage.reindex(order).fillna(value=0)

print "Data:"
print profile
print ""
print "Data %:"
print profile_percentage
# Out:
# Data:
# I did not notice an organized system, the differences between these entities were not clear         2.0
# There was a system with a certain structure, and I understood it                                    5.0
# There was a system with a certain structure, and I understood it and designed it with the others    0.0
# No answer                                                                                           1.0
# Name: Q29, dtype: float64
#
# Data %:
# I did not notice an organized system, the differences between these entities were not clear         25.0
# There was a system with a certain structure, and I understood it                                    62.5
# There was a system with a certain structure, and I understood it and designed it with the others     0.0
# No answer                                                                                           12.5
# Name: Q29, dtype: float64

# %%
# Configure font
matplotlib.rcParams['font.sans-serif'] = "Fira Sans"
matplotlib.rcParams['font.family'] = "sans-serif"
sns.set_context("paper")
# Plot the data
plt.figure(figsize=(8,6))
plt.xlabel('Count', fontsize=16)
plt.ylabel('Participants', fontsize=16)
title = u"Q29. How did you experience the whole systems (actors, roles, interactions, organizations, places) during this research study?"
plt.title("\n".join(wrap(title, 70)), fontsize=22, y=1.02, fontname='Fira Sans', fontweight="500")
my_colors = sns.color_palette("husl", len(profile)) # Set color palette
profile.plot(kind='barh', color=my_colors, alpha=0.75, rot=0, figsize=(15,10))
labels = ['\n'.join(wrap(l, 30)) for l in profile.index]
plt.yticks(range(len(labels)), labels, fontsize=14)
plt.xticks(fontsize=14)
for i, v in enumerate(profile):
    plt.text(v + .1, i, str(v)+" ("+str(profile_percentage[i])+"%)", fontweight='500', fontsize=14)
plt.savefig("svg/Q29.svg", bbox_inches="tight")
plt.savefig("png/Q29.png", dpi=300, bbox_inches="tight")
